# %% [markdown]
# ## 酶活性预测实战task：
# 1、基于T-R-train.csv数据，建立线性回归模型，计算其在T-R-test.csv数据上的r2分数，可视化模型预测结果
# 2、加入多项式特征（2次、5次），建立回归模型
# 3、计算多项式回归模型对测试数据进行预测的r2分数，判断哪个模型预测更准确
# 4、可视化多项式回归模型数据预测结果，判断哪个模型预测更准确

# %%
# load the data
import pandas as pd
import numpy as np
import sys
sys.path.append('../')

# %%
data_train = pd.read_csv('../T-R-train.csv')
data_train
# Out:
#         T  rate
# 0   46.53  2.49
# 1   48.14  2.56
# 2   50.15  2.63
# 3   51.36  2.69
# 4   52.57  2.74
# 5   54.18  2.80
# 6   56.19  2.88
# 7   58.58  2.92
# 8   61.37  2.96
# 9   63.34  2.95
# 10  65.31  2.91
# 11  66.47  2.85
# 12  68.03  2.78
# 13  69.97  2.69
# 14  71.13  2.61
# 15  71.89  2.54
# 16  73.05  2.45
# 17  74.21  2.39

# %%
# define X and y
X_train = data_train.loc[:, 'T']
y_train = data_train.loc[:, 'rate']
print(X_train)
# Out:
# 0     46.53
# 1     48.14
# 2     50.15
# 3     51.36
# 4     52.57
# 5     54.18
# 6     56.19
# 7     58.58
# 8     61.37
# 9     63.34
# 10    65.31
# 11    66.47
# 12    68.03
# 13    69.97
# 14    71.13
# 15    71.89
# 16    73.05
# 17    74.21
# Name: T, dtype: float64

# %%
# vusualize the data
# %matplotlib inline
from matplotlib import pyplot as plt
fig1 = plt.figure(figsize=(5, 5))
plt.scatter(X_train, y_train)
plt.title("x_train raw data") 
plt.xlabel('temperature')
plt.ylabel('rate')
plt.show()

# %%
# x升维， 为了训练线性回归
X_train = np.array(X_train).reshape(-1, 1)

# %%
# build the model
from sklearn.linear_model import LinearRegression

lr1 = LinearRegression()
lr1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# load the test data to evaluate the model lr1
data_test = pd.read_csv("../T-R-test.csv")
data_test
# Out:
#            T      rate
# 0  45.376344  2.334559
# 1  52.186380  2.775735
# 2  61.863799  2.930147
# 3  73.154122  2.488971
# 4  78.888889  1.981618
# 5  82.473118  1.518382
# 6  43.046595  2.080882

# %%
# defind x an y
X_test = data_test.loc[:, 'T']
X_test = np.array(X_test).reshape(-1, 1)
y_test = data_test.loc[:, 'rate']

# %%
# predict the y
y_train_predict = lr1.predict(X_train)
y_test_predict = lr1.predict(X_test)

from sklearn.metrics import r2_score
r2_train = r2_score(y_train, y_train_predict)
r2_test = r2_score(y_test, y_test_predict)

print('train r2 ', r2_train)
print('test r2 ', r2_test)
# Out:
# train r2  0.016665703886981964
# test r2  -0.758336343735132

# %%
# generate the new data to plot the model
X_range = np.linspace(40, 90, 300).reshape(-1, 1)
y_range_predict = lr1.predict(X_range)

# %%
# plot the model
def plot_model(X, y, x_range, y_range_predict, title):
    fig2 = plt.figure(figsize=(5, 5))

    plt.scatter(X, y)
    plt.xlabel("temperature")
    plt.ylabel("rate")
    plt.title(title)

    plt.plot(x_range, y_range_predict)
    plt.show()

plot_model(X_train, y_train, X_range, y_range_predict, "train data vs lr1 model")

# %% [markdown]
# 从上面的图像中，可以看出 lr1模型是 一条直线，和train data 不是很符合， 需要对模型 进行升维

# %% [markdown]
# ### 对x feature 升维
# 手写升维方法

# %%
# 多项式 模型 polynomial

# 手动添加一个x2  x2 = x1 * x1

def create_more_features(x, n):
    """
    Args:
    x is the original train data, numpy array (, 1)
    n is the highest Degree of a polynomial
    """
    # take the first the column as the base
    x1 = x[:, 0].reshape(-1, 1)

    # copy the original features matrix
    res = np.copy(x1)

    for i in range(2, n + 1):
        x_i = np.power(x1, i)
        res = np.append(res, x_i, 1)
    return res

X_train_2 = create_more_features(X_train, 2)
X_test_2 = create_more_features(X_test, 2)

# %%
# establish the new high order model
# 建立一个2次的线性模型
my_lr2 = LinearRegression()
my_lr2.fit(X_train_2, y_train)
# Out:
# LinearRegression()

# %%
y_train_predict_2 = my_lr2.predict(X_train_2)
y_test_predict_2 = my_lr2.predict(X_test_2)

# %%
r2_train = r2_score(y_train, y_train_predict_2)
r2_test = r2_score(y_test, y_test_predict_2)

print('train r2 on my_lr2', r2_train)
print('test r2 on my_lr2', r2_test)
# Out:
# train r2 on lr2 0.9700515400689428
# test r2 on lr2 0.9963954556468576

# %% [markdown]
# 可以看出 r2 值大幅度提高

# %%
# generate the new data to plot the model
X_range_2 = create_more_features(X_range, 2)
y_range_predict_2 = my_lr2.predict(X_range_2)

# %%
# plot the new model
plot_model(X_train, y_train, X_range, y_range_predict_2, "train data vs my_lr2 model")

# %% [markdown]
# ### 对x feature 升维
# 采用sklearn 自带的方法

# %%
# 多形式模型
from sklearn.preprocessing import PolynomialFeatures
poly_2 = PolynomialFeatures(degree=2)
X_2_train = poly_2.fit_transform(X_train)
X_2_test = poly_2.transform(X_test)

# 5次的多项式
poly5 = PolynomialFeatures(degree=5)
X_5_train = poly5.fit_transform(X_train)
X_5_test = poly5.transform(X_test)
print(X_5_train.shape)
# Out:
# (18, 6)

# %%
lr2 = LinearRegression()
lr2.fit(X_2_train,y_train)
# Out:
# LinearRegression()

# %%
# evaluate 
y_2_train_predict = lr2.predict(X_2_train)
y_2_test_predict = lr2.predict(X_2_test)

r2_2_score = r2_score(y_train, y_2_train_predict)
r2_2_test = r2_score(y_test, y_2_test_predict)

print('train r2 score on lr2', r2_2_score)
print('test r2 score on lr2', r2_2_test)
# Out:
# train r2 score on lr2 0.970051540068942
# test r2 score on lr2 0.9963954556468684

# %%
lr5 = LinearRegression()
lr5.fit(X_5_train,y_train)
# Out:
# LinearRegression()

# %%
y_5_train_predict = lr5.predict(X_5_train)
y_5_test_predict = lr5.predict(X_5_test)
r2_5_train = r2_score(y_train,y_5_train_predict)
r2_5_test = r2_score(y_test,y_5_test_predict)

# %%
print('training r2_5:',r2_5_train)
print('test r2_5:',r2_5_test)
# Out:
# training r2_5: 0.9978527267187658
# test r2_5: 0.5437837627379174

# %%
# plot 

X_2_range = np.linspace(40, 90, 300).reshape(-1, 1)
X_2_range = poly_2.transform(X_2_range)
y_2_range_predict = lr2.predict(X_2_range)


X_5_range = np.linspace(40, 90, 300).reshape(-1, 1)
X_5_range = poly5.transform(X_5_range)
y_5_predict = lr5.predict(X_5_range)

# %%
fig3 = plt.figure(figsize=(5,5))
plt.plot(X_range,y_2_range_predict)
plt.scatter(X_train,y_train)
plt.scatter(X_test,y_test)

plt.title('polynomial prediction result (2)')
plt.xlabel('temperature')
plt.ylabel('rate')
plt.show()

# %%
fig4 = plt.figure(figsize=(5, 5))
plt.plot(X_range, y_5_predict)
plt.scatter(X_train,y_train)
plt.scatter(X_test,y_test)

plt.title("polynomial prediction resutl (5)")
plt.xlabel("tempature")
plt.ylabel("rate")
plt.show()

# %% [markdown]
# 酶活性预测实战summary：
# 1、通过建立二阶多项式回归模型，对酶活性实现了一个较好的预测，无论针对训练或测试数据都得到一个高的r2分数；
# 2、通过建立线性回归、五阶多项式回归模型，发现存在过拟合或欠拟合情况。过拟合情况下，对于训练数据r2分数高（预测准确），但对于预测数据r2分数低（预测不准确）;
# 3、无论时通过r2分数，或是可视化模型结果，都可以发现二阶多项式回归模型效果最好
# 4、核心算法参考链接：https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression
