# %% [markdown]
# ## Matplotlib learning Notes

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Plot 函数
#
# x, y 分别表示x轴 y轴的坐标点

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

plt.plot(x, y)
plt.plot(x, y, 'o')  # 'o' for dots 用来画点
plt.show()
